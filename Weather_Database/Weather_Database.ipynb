# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | port elizabeth
# Processing Record 5 of Set 1 | port hawkesbury
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | puerto ayora
# Processing Record 8 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 1 | razole
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | panzhihua
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | mercedes
# Processing Record 19 of Set 1 | adrar
# Processing Record 20 of Set 1 | emerald
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | talaya
# Processing Record 23 of Set 1 | juneau
# Processing Record 24 of Set 1 | clyde river
# Processing Record 25 of Set 1 | port hedland
# Processing Record 26 of Set 1 | souillac
# Processing Record 27 of Set 1 | qaqortoq
# Processing Record 28 of Set 1 | auki
# Processing Record 29 of Set 1 | kanlagay
# Processing Record 30 of Set 1 | ancud
# Processing Record 31 of Set 1 | mahibadhoo
# Processing Record 32 of Set 1 | dunedin
# Processing Record 33 of Set 1 | east london
# Processing Record 34 of Set 1 | komsomolskiy
# Processing Record 35 of Set 1 | khatanga
# Processing Record 36 of Set 1 | lebu
# Processing Record 37 of Set 1 | cabo san lucas
# Processing Record 38 of Set 1 | abalak
# Processing Record 39 of Set 1 | hilo
# Processing Record 40 of Set 1 | jinka
# Processing Record 41 of Set 1 | pamfila
# Processing Record 42 of Set 1 | ahipara
# Processing Record 43 of Set 1 | mata
# Processing Record 44 of Set 1 | saint-augustin
# Processing Record 45 of Set 1 | chokurdakh
# Processing Record 46 of Set 1 | olafsvik
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | vardo
# Processing Record 49 of Set 1 | bam
# Processing Record 50 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 2 | aguilar de la frontera
# Processing Record 3 of Set 2 | arraial do cabo
# Processing Record 4 of Set 2 | atuona
# Processing Record 5 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 2 | moussoro
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | ardahan
# Processing Record 9 of Set 2 | meulaboh
# Processing Record 10 of Set 2 | saint george
# Processing Record 11 of Set 2 | homer
# Processing Record 12 of Set 2 | camocim
# Processing Record 13 of Set 2 | bluff
# Processing Record 14 of Set 2 | ponta do sol
# Processing Record 15 of Set 2 | castro
# Processing Record 16 of Set 2 | kruisfontein
# Processing Record 17 of Set 2 | zhanaozen
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | mandalgovi
# Processing Record 20 of Set 2 | ukiah
# Processing Record 21 of Set 2 | ardistan
# City not found. Skipping...
# Processing Record 22 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 23 of Set 2 | coihaique
# Processing Record 24 of Set 2 | torbay
# Processing Record 25 of Set 2 | basco
# Processing Record 26 of Set 2 | cidreira
# Processing Record 27 of Set 2 | mnogovershinnyy
# Processing Record 28 of Set 2 | coquimbo
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | sarankhola
# Processing Record 31 of Set 2 | xinan
# Processing Record 32 of Set 2 | rawson
# Processing Record 33 of Set 2 | rikitea
# Processing Record 34 of Set 2 | alice springs
# Processing Record 35 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 2 | talnakh
# Processing Record 37 of Set 2 | wittlich
# Processing Record 38 of Set 2 | barrow
# Processing Record 39 of Set 2 | severo-kurilsk
# Processing Record 40 of Set 2 | ponta delgada
# Processing Record 41 of Set 2 | neiafu
# Processing Record 42 of Set 2 | erzincan
# Processing Record 43 of Set 2 | bambous virieux
# Processing Record 44 of Set 2 | butaritari
# Processing Record 45 of Set 2 | bredasdorp
# Processing Record 46 of Set 2 | margate
# Processing Record 47 of Set 2 | faanui
# Processing Record 48 of Set 2 | sale
# Processing Record 49 of Set 2 | provideniya
# Processing Record 50 of Set 2 | hamilton
# Processing Record 1 of Set 3 | hobyo
# Processing Record 2 of Set 3 | rio grande
# Processing Record 3 of Set 3 | dubrovytsya
# Processing Record 4 of Set 3 | beringovskiy
# Processing Record 5 of Set 3 | saskylakh
# Processing Record 6 of Set 3 | naze
# Processing Record 7 of Set 3 | kaitangata
# Processing Record 8 of Set 3 | alyangula
# Processing Record 9 of Set 3 | beyla
# Processing Record 10 of Set 3 | mataura
# Processing Record 11 of Set 3 | upernavik
# Processing Record 12 of Set 3 | hargeysa
# Processing Record 13 of Set 3 | ketchikan
# Processing Record 14 of Set 3 | khor
# Processing Record 15 of Set 3 | longyan
# Processing Record 16 of Set 3 | carnarvon
# Processing Record 17 of Set 3 | cape town
# Processing Record 18 of Set 3 | mahebourg
# Processing Record 19 of Set 3 | calama
# Processing Record 20 of Set 3 | zhanakorgan
# Processing Record 21 of Set 3 | albany
# Processing Record 22 of Set 3 | mount gambier
# Processing Record 23 of Set 3 | severomorsk
# Processing Record 24 of Set 3 | phetchaburi
# Processing Record 25 of Set 3 | kasongo-lunda
# Processing Record 26 of Set 3 | sechura
# Processing Record 27 of Set 3 | lagoa
# Processing Record 28 of Set 3 | saldanha
# Processing Record 29 of Set 3 | loa janan
# Processing Record 30 of Set 3 | esperance
# Processing Record 31 of Set 3 | henties bay
# Processing Record 32 of Set 3 | bay roberts
# Processing Record 33 of Set 3 | sinegorye
# Processing Record 34 of Set 3 | chuy
# Processing Record 35 of Set 3 | takestan
# Processing Record 36 of Set 3 | port hueneme
# Processing Record 37 of Set 3 | imeni poliny osipenko
# Processing Record 38 of Set 3 | christchurch
# Processing Record 39 of Set 3 | new norfolk
# Processing Record 40 of Set 3 | cherskiy
# Processing Record 41 of Set 3 | santa vitoria do palmar
# Processing Record 42 of Set 3 | kavieng
# Processing Record 43 of Set 3 | siguiri
# Processing Record 44 of Set 3 | asau
# Processing Record 45 of Set 3 | sao filipe
# Processing Record 46 of Set 3 | ariquemes
# Processing Record 47 of Set 3 | tautira
# Processing Record 48 of Set 3 | bani walid
# Processing Record 49 of Set 3 | monte patria
# Processing Record 50 of Set 3 | svobodnyy
# Processing Record 1 of Set 4 | osmaniye
# Processing Record 2 of Set 4 | coahuayana
# Processing Record 3 of Set 4 | grand-santi
# Processing Record 4 of Set 4 | bethel
# Processing Record 5 of Set 4 | stoughton
# Processing Record 6 of Set 4 | krasnoselkup
# Processing Record 7 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 4 | pisco
# Processing Record 9 of Set 4 | la ronge
# Processing Record 10 of Set 4 | okhotsk
# Processing Record 11 of Set 4 | missoula
# Processing Record 12 of Set 4 | hanmer springs
# Processing Record 13 of Set 4 | sept-iles
# Processing Record 14 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 4 | bonavista
# Processing Record 16 of Set 4 | bara
# Processing Record 17 of Set 4 | geraldton
# Processing Record 18 of Set 4 | tevaitoa
# Processing Record 19 of Set 4 | kodiak
# Processing Record 20 of Set 4 | launceston
# Processing Record 21 of Set 4 | leningradskiy
# Processing Record 22 of Set 4 | san joaquin
# Processing Record 23 of Set 4 | yatou
# Processing Record 24 of Set 4 | araouane
# Processing Record 25 of Set 4 | baykit
# Processing Record 26 of Set 4 | axim
# Processing Record 27 of Set 4 | moree
# Processing Record 28 of Set 4 | luanda
# Processing Record 29 of Set 4 | touros
# Processing Record 30 of Set 4 | sucua
# Processing Record 31 of Set 4 | aripuana
# Processing Record 32 of Set 4 | sayyan
# Processing Record 33 of Set 4 | lavrentiya
# Processing Record 34 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 4 | nikolskoye
# Processing Record 36 of Set 4 | bristol
# Processing Record 37 of Set 4 | kawalu
# Processing Record 38 of Set 4 | zhucheng
# Processing Record 39 of Set 4 | pitkyaranta
# Processing Record 40 of Set 4 | conde
# Processing Record 41 of Set 4 | camacha
# Processing Record 42 of Set 4 | tura
# Processing Record 43 of Set 4 | guerrero negro
# Processing Record 44 of Set 4 | cooma
# Processing Record 45 of Set 4 | fukue
# Processing Record 46 of Set 4 | nome
# Processing Record 47 of Set 4 | samoylovka
# Processing Record 48 of Set 4 | balakovo
# Processing Record 49 of Set 4 | yulara
# Processing Record 50 of Set 4 | victoria
# Processing Record 1 of Set 5 | qaanaaq
# Processing Record 2 of Set 5 | goderich
# Processing Record 3 of Set 5 | wajir
# Processing Record 4 of Set 5 | skibbereen
# Processing Record 5 of Set 5 | rudbar
# Processing Record 6 of Set 5 | khairagarh
# Processing Record 7 of Set 5 | tasiilaq
# Processing Record 8 of Set 5 | verkhnyaya inta
# Processing Record 9 of Set 5 | santa maria
# Processing Record 10 of Set 5 | mar del plata
# Processing Record 11 of Set 5 | teya
# Processing Record 12 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 5 | novikovo
# Processing Record 14 of Set 5 | aksarka
# Processing Record 15 of Set 5 | varnamo
# Processing Record 16 of Set 5 | sabya
# Processing Record 17 of Set 5 | arlit
# Processing Record 18 of Set 5 | qasigiannguit
# Processing Record 19 of Set 5 | sabang
# Processing Record 20 of Set 5 | preobrazheniye
# Processing Record 21 of Set 5 | erzin
# Processing Record 22 of Set 5 | nalut
# Processing Record 23 of Set 5 | ilulissat
# Processing Record 24 of Set 5 | dingle
# Processing Record 25 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 5 | san patricio
# Processing Record 27 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 5 | yarkovo
# Processing Record 29 of Set 5 | tuatapere
# Processing Record 30 of Set 5 | netivot
# Processing Record 31 of Set 5 | srednekolymsk
# Processing Record 32 of Set 5 | menomonie
# Processing Record 33 of Set 5 | ciudad bolivar
# Processing Record 34 of Set 5 | luderitz
# Processing Record 35 of Set 5 | cayenne
# Processing Record 36 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 5 | maarianhamina
# Processing Record 38 of Set 5 | hervey bay
# Processing Record 39 of Set 5 | matay
# Processing Record 40 of Set 5 | bandarbeyla
# Processing Record 41 of Set 5 | intipuca
# Processing Record 42 of Set 5 | hithadhoo
# Processing Record 43 of Set 5 | tema
# Processing Record 44 of Set 5 | vanavara
# Processing Record 45 of Set 5 | makakilo city
# Processing Record 46 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 5 | eatontown
# Processing Record 48 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 5 | vestmannaeyjar
# Processing Record 50 of Set 5 | nabire
# Processing Record 1 of Set 6 | port blair
# Processing Record 2 of Set 6 | leticia
# Processing Record 3 of Set 6 | padilla
# Processing Record 4 of Set 6 | vila franca do campo
# Processing Record 5 of Set 6 | bjorkelangen
# Processing Record 6 of Set 6 | nishihara
# Processing Record 7 of Set 6 | huilong
# Processing Record 8 of Set 6 | buchanan
# Processing Record 9 of Set 6 | whitehaven
# Processing Record 10 of Set 6 | south venice
# Processing Record 11 of Set 6 | muravlenko
# Processing Record 12 of Set 6 | davila
# Processing Record 13 of Set 6 | buraydah
# Processing Record 14 of Set 6 | bathsheba
# Processing Record 15 of Set 6 | padang
# Processing Record 16 of Set 6 | liku
# Processing Record 17 of Set 6 | safaga
# Processing Record 18 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 6 | katsuura
# Processing Record 20 of Set 6 | sheffield
# Processing Record 21 of Set 6 | along
# Processing Record 22 of Set 6 | barabinsk
# Processing Record 23 of Set 6 | airai
# Processing Record 24 of Set 6 | linxia
# Processing Record 25 of Set 6 | zhuhai
# Processing Record 26 of Set 6 | evensk
# Processing Record 27 of Set 6 | nelson bay
# Processing Record 28 of Set 6 | prince rupert
# Processing Record 29 of Set 6 | ostrovnoy
# Processing Record 30 of Set 6 | saint-pierre
# Processing Record 31 of Set 6 | peniche
# Processing Record 32 of Set 6 | belogorsk
# Processing Record 33 of Set 6 | garowe
# Processing Record 34 of Set 6 | beidao
# Processing Record 35 of Set 6 | antofagasta
# Processing Record 36 of Set 6 | thompson
# Processing Record 37 of Set 6 | mehran
# Processing Record 38 of Set 6 | gangapur
# Processing Record 39 of Set 6 | beruwala
# Processing Record 40 of Set 6 | guaratuba
# Processing Record 41 of Set 6 | svarstad
# Processing Record 42 of Set 6 | gaillac
# Processing Record 43 of Set 6 | qax
# Processing Record 44 of Set 6 | anadyr
# Processing Record 45 of Set 6 | tiksi
# Processing Record 46 of Set 6 | lichinga
# Processing Record 47 of Set 6 | songjianghe
# Processing Record 48 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 49 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 50 of Set 6 | bengkulu
# Processing Record 1 of Set 7 | reconquista
# Processing Record 2 of Set 7 | palora
# Processing Record 3 of Set 7 | pemangkat
# Processing Record 4 of Set 7 | agarakadzor
# Processing Record 5 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 6 of Set 7 | svetlyy
# Processing Record 7 of Set 7 | la asuncion
# Processing Record 8 of Set 7 | black forest
# Processing Record 9 of Set 7 | hambantota
# Processing Record 10 of Set 7 | ovalle
# Processing Record 11 of Set 7 | paamiut
# Processing Record 12 of Set 7 | hofn
# Processing Record 13 of Set 7 | toamasina
# Processing Record 14 of Set 7 | lata
# Processing Record 15 of Set 7 | cedar city
# Processing Record 16 of Set 7 | tefe
# Processing Record 17 of Set 7 | nanortalik
# Processing Record 18 of Set 7 | seinajoki
# Processing Record 19 of Set 7 | namibe
# Processing Record 20 of Set 7 | oussouye
# Processing Record 21 of Set 7 | gomel
# Processing Record 22 of Set 7 | narsaq
# Processing Record 23 of Set 7 | klaksvik
# Processing Record 24 of Set 7 | hit
# Processing Record 25 of Set 7 | owando
# Processing Record 26 of Set 7 | porto san giorgio
# Processing Record 27 of Set 7 | grado
# Processing Record 28 of Set 7 | kopavogur
# Processing Record 29 of Set 7 | kahului
# Processing Record 30 of Set 7 | zyryanka
# Processing Record 31 of Set 7 | bagan
# Processing Record 32 of Set 7 | tilichiki
# Processing Record 33 of Set 7 | aykhal
# Processing Record 34 of Set 7 | xadani
# City not found. Skipping...
# Processing Record 35 of Set 7 | grand gaube
# Processing Record 36 of Set 7 | huarmey
# Processing Record 37 of Set 7 | saint-francois
# Processing Record 38 of Set 7 | port augusta
# Processing Record 39 of Set 7 | neryungri
# Processing Record 40 of Set 7 | cowansville
# Processing Record 41 of Set 7 | abnub
# Processing Record 42 of Set 7 | wum
# Processing Record 43 of Set 7 | havelock
# Processing Record 44 of Set 7 | xining
# Processing Record 45 of Set 7 | edd
# Processing Record 46 of Set 7 | general roca
# Processing Record 47 of Set 7 | willowmore
# Processing Record 48 of Set 7 | ribeira grande
# Processing Record 49 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 50 of Set 7 | hasaki
# Processing Record 1 of Set 8 | tecoanapa
# Processing Record 2 of Set 8 | mashhad
# Processing Record 3 of Set 8 | khasan
# Processing Record 4 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 8 | tinskoy
# Processing Record 6 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 7 of Set 8 | zhanatas
# City not found. Skipping...
# Processing Record 8 of Set 8 | kayunga
# Processing Record 9 of Set 8 | pathein
# Processing Record 10 of Set 8 | dole
# Processing Record 11 of Set 8 | manzanillo
# Processing Record 12 of Set 8 | andenes
# Processing Record 13 of Set 8 | dokka
# Processing Record 14 of Set 8 | kuusamo
# Processing Record 15 of Set 8 | itoman
# Processing Record 16 of Set 8 | kiri buru
# Processing Record 17 of Set 8 | faya
# Processing Record 18 of Set 8 | magaria
# Processing Record 19 of Set 8 | alofi
# Processing Record 20 of Set 8 | miles city
# Processing Record 21 of Set 8 | norman wells
# Processing Record 22 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 8 | turayf
# Processing Record 24 of Set 8 | jiuquan
# Processing Record 25 of Set 8 | balimo
# City not found. Skipping...
# Processing Record 26 of Set 8 | yabelo
# Processing Record 27 of Set 8 | mitu
# Processing Record 28 of Set 8 | kunming
# Processing Record 29 of Set 8 | novi travnik
# Processing Record 30 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 8 | caravelas
# Processing Record 32 of Set 8 | nizwa
# Processing Record 33 of Set 8 | selenginsk
# Processing Record 34 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 8 | the pas
# Processing Record 36 of Set 8 | caala
# Processing Record 37 of Set 8 | constitucion
# Processing Record 38 of Set 8 | codrington
# Processing Record 39 of Set 8 | kalmunai
# Processing Record 40 of Set 8 | grants pass
# Processing Record 41 of Set 8 | kalabo
# Processing Record 42 of Set 8 | iqaluit
# Processing Record 43 of Set 8 | caucaia
# Processing Record 44 of Set 8 | jorochito
# Processing Record 45 of Set 8 | lompoc
# Processing Record 46 of Set 8 | victoria point
# Processing Record 47 of Set 8 | iracoubo
# Processing Record 48 of Set 8 | eyl
# Processing Record 49 of Set 8 | coffs harbour
# Processing Record 50 of Set 8 | longyearbyen
# Processing Record 1 of Set 9 | bahar
# Processing Record 2 of Set 9 | mlawa
# Processing Record 3 of Set 9 | shache
# Processing Record 4 of Set 9 | isla mujeres
# Processing Record 5 of Set 9 | dwarka
# Processing Record 6 of Set 9 | nioro
# Processing Record 7 of Set 9 | vodnyy
# Processing Record 8 of Set 9 | rock springs
# Processing Record 9 of Set 9 | honningsvag
# Processing Record 10 of Set 9 | northam
# Processing Record 11 of Set 9 | yarada
# Processing Record 12 of Set 9 | novonikolayevskiy
# Processing Record 13 of Set 9 | whyalla
# Processing Record 14 of Set 9 | kaohsiung
# Processing Record 15 of Set 9 | rheinau
# Processing Record 16 of Set 9 | yeppoon
# Processing Record 17 of Set 9 | caorle
# Processing Record 18 of Set 9 | basoko
# Processing Record 19 of Set 9 | mandera
# Processing Record 20 of Set 9 | maniitsoq
# Processing Record 21 of Set 9 | baruun-urt
# Processing Record 22 of Set 9 | srivardhan
# Processing Record 23 of Set 9 | carinhanha
# Processing Record 24 of Set 9 | kitimat
# Processing Record 25 of Set 9 | mimongo
# Processing Record 26 of Set 9 | wanning
# Processing Record 27 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 9 | aklavik
# Processing Record 29 of Set 9 | burgersdorp
# Processing Record 30 of Set 9 | ugoofaaru
# Processing Record 31 of Set 9 | dhidhdhoo
# Processing Record 32 of Set 9 | fortuna
# Processing Record 33 of Set 9 | poum
# Processing Record 34 of Set 9 | puerto maldonado
# Processing Record 35 of Set 9 | zhigansk
# Processing Record 36 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 37 of Set 9 | crab hill
# City not found. Skipping...
# Processing Record 38 of Set 9 | linjiang
# Processing Record 39 of Set 9 | marawi
# Processing Record 40 of Set 9 | ye
# City not found. Skipping...
# Processing Record 41 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 42 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 9 | zeya
# Processing Record 44 of Set 9 | derby
# Processing Record 45 of Set 9 | kaeo
# Processing Record 46 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 9 | lorengau
# Processing Record 48 of Set 9 | lakes entrance
# Processing Record 49 of Set 9 | coueron
# Processing Record 50 of Set 9 | lagos
# Processing Record 1 of Set 10 | moose factory
# Processing Record 2 of Set 10 | gat
# Processing Record 3 of Set 10 | khorixas
# Processing Record 4 of Set 10 | seoul
# Processing Record 5 of Set 10 | bonthe
# Processing Record 6 of Set 10 | labuhan
# Processing Record 7 of Set 10 | sitka
# Processing Record 8 of Set 10 | mareeba
# Processing Record 9 of Set 10 | sosenskiy
# Processing Record 10 of Set 10 | jennings
# Processing Record 11 of Set 10 | manutuke
# Processing Record 12 of Set 10 | derzhavinsk
# Processing Record 13 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 10 | arcelia
# Processing Record 15 of Set 10 | burkhala
# City not found. Skipping...
# Processing Record 16 of Set 10 | rocha
# Processing Record 17 of Set 10 | oshikango
# Processing Record 18 of Set 10 | pavlovsk
# Processing Record 19 of Set 10 | brae
# Processing Record 20 of Set 10 | sobolevo
# Processing Record 21 of Set 10 | campbell river
# Processing Record 22 of Set 10 | sikeston
# Processing Record 23 of Set 10 | pinawa
# Processing Record 24 of Set 10 | viesite
# Processing Record 25 of Set 10 | saint anthony
# Processing Record 26 of Set 10 | wajima
# Processing Record 27 of Set 10 | waingapu
# Processing Record 28 of Set 10 | port lincoln
# Processing Record 29 of Set 10 | bridlington
# Processing Record 30 of Set 10 | ulladulla
# Processing Record 31 of Set 10 | winona
# Processing Record 32 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 33 of Set 10 | zhengjiatun
# Processing Record 34 of Set 10 | tual
# Processing Record 35 of Set 10 | ixtapa
# Processing Record 36 of Set 10 | lenine
# Processing Record 37 of Set 10 | tazovskiy
# Processing Record 38 of Set 10 | gurgan
# City not found. Skipping...
# Processing Record 39 of Set 10 | guangyuan
# Processing Record 40 of Set 10 | abha
# Processing Record 41 of Set 10 | presidente medici
# Processing Record 42 of Set 10 | buala
# Processing Record 43 of Set 10 | ilheus
# Processing Record 44 of Set 10 | belmonte
# Processing Record 45 of Set 10 | la baneza
# Processing Record 46 of Set 10 | carman
# Processing Record 47 of Set 10 | samsun
# Processing Record 48 of Set 10 | synya
# Processing Record 49 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 50 of Set 10 | na klang
# Processing Record 1 of Set 11 | kavaratti
# Processing Record 2 of Set 11 | mehamn
# Processing Record 3 of Set 11 | malanje
# Processing Record 4 of Set 11 | san isidro
# Processing Record 5 of Set 11 | megara
# Processing Record 6 of Set 11 | ashland
# Processing Record 7 of Set 11 | islamkot
# Processing Record 8 of Set 11 | isangel
# Processing Record 9 of Set 11 | chamba
# Processing Record 10 of Set 11 | pacific grove
# Processing Record 11 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 12 of Set 11 | yenagoa
# Processing Record 13 of Set 11 | katherine
# Processing Record 14 of Set 11 | marrakesh
# Processing Record 15 of Set 11 | mato verde
# Processing Record 16 of Set 11 | kloulklubed
# Processing Record 17 of Set 11 | freeport
# Processing Record 18 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 19 of Set 11 | comodoro rivadavia
# Processing Record 20 of Set 11 | castelo do piaui
# Processing Record 21 of Set 11 | saint-philippe
# Processing Record 22 of Set 11 | sherbakul
# Processing Record 23 of Set 11 | madang
# Processing Record 24 of Set 11 | cognac
# Processing Record 25 of Set 11 | salalah
# Processing Record 26 of Set 11 | natal
# Processing Record 27 of Set 11 | ullapool
# Processing Record 28 of Set 11 | russell
# Processing Record 29 of Set 11 | vao
# Processing Record 30 of Set 11 | barranca
# Processing Record 31 of Set 11 | abonnema
# Processing Record 32 of Set 11 | tukrah
# Processing Record 33 of Set 11 | trairi
# Processing Record 34 of Set 11 | megion
# Processing Record 35 of Set 11 | santa cruz
# Processing Record 36 of Set 11 | te anau
# Processing Record 37 of Set 11 | tuntum
# Processing Record 38 of Set 11 | avera
# Processing Record 39 of Set 11 | atambua
# Processing Record 40 of Set 11 | presidencia roque saenz pena
# Processing Record 41 of Set 11 | fort nelson
# Processing Record 42 of Set 11 | parana
# Processing Record 43 of Set 11 | awjilah
# Processing Record 44 of Set 11 | nieves
# Processing Record 45 of Set 11 | beloha
# Processing Record 46 of Set 11 | gamba
# Processing Record 47 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 48 of Set 11 | dutlwe
# Processing Record 49 of Set 11 | madimba
# Processing Record 50 of Set 11 | parvatsar
# Processing Record 1 of Set 12 | biak
# Processing Record 2 of Set 12 | amargosa
# Processing Record 3 of Set 12 | sola
# Processing Record 4 of Set 12 | pombas
# Processing Record 5 of Set 12 | jumla
# Processing Record 6 of Set 12 | alferrarede
# Processing Record 7 of Set 12 | pevek
# Processing Record 8 of Set 12 | balikpapan
# Processing Record 9 of Set 12 | sindor
# Processing Record 10 of Set 12 | hukuntsi
# Processing Record 11 of Set 12 | nosy varika
# Processing Record 12 of Set 12 | nova olimpia
# Processing Record 13 of Set 12 | moron
# Processing Record 14 of Set 12 | hun
# Processing Record 15 of Set 12 | samarai
# Processing Record 16 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 12 | chicama
# Processing Record 18 of Set 12 | anzio
# Processing Record 19 of Set 12 | kupang
# Processing Record 20 of Set 12 | maldonado
# Processing Record 21 of Set 12 | umm lajj
# Processing Record 22 of Set 12 | bushehr
# Processing Record 23 of Set 12 | taga
# Processing Record 24 of Set 12 | kankon
# Processing Record 25 of Set 12 | north bend
# Processing Record 26 of Set 12 | sinnamary
# Processing Record 27 of Set 12 | ajdabiya
# Processing Record 28 of Set 12 | cabedelo
# Processing Record 29 of Set 12 | falakata
# Processing Record 30 of Set 12 | jieshi
# Processing Record 31 of Set 12 | ribas do rio pardo
# Processing Record 32 of Set 12 | tandil
# Processing Record 33 of Set 12 | guaruja
# Processing Record 34 of Set 12 | rotterdam
# Processing Record 35 of Set 12 | lyaskelya
# Processing Record 36 of Set 12 | newport
# Processing Record 37 of Set 12 | kishi
# Processing Record 38 of Set 12 | mwanza
# Processing Record 39 of Set 12 | khortiatis
# City not found. Skipping...
# Processing Record 40 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 41 of Set 12 | taburi
# City not found. Skipping...
# Processing Record 42 of Set 12 | san antonio
# Processing Record 43 of Set 12 | mgandu
# Processing Record 44 of Set 12 | chandur bazar
# Processing Record 45 of Set 12 | conceicao do araguaia
# Processing Record 46 of Set 12 | puerto ayacucho
# Processing Record 47 of Set 12 | mount isa
# Processing Record 48 of Set 12 | amazar
# Processing Record 49 of Set 12 | chivilcoy
# Processing Record 50 of Set 12 | acapulco
# Processing Record 1 of Set 13 | kurilsk
# Processing Record 2 of Set 13 | makhinjauri
# Processing Record 3 of Set 13 | sur
# Processing Record 4 of Set 13 | stornoway
# Processing Record 5 of Set 13 | itamaraju
# Processing Record 6 of Set 13 | ballina
# Processing Record 7 of Set 13 | mecca
# Processing Record 8 of Set 13 | le moule
# Processing Record 9 of Set 13 | soe
# Processing Record 10 of Set 13 | bambanglipuro
# Processing Record 11 of Set 13 | tingo maria
# Processing Record 12 of Set 13 | somerset east
# Processing Record 13 of Set 13 | kozulka
# Processing Record 14 of Set 13 | ayagoz
# Processing Record 15 of Set 13 | ankara
# Processing Record 16 of Set 13 | vidalia
# Processing Record 17 of Set 13 | svetlogorsk
# Processing Record 18 of Set 13 | kamenka
# Processing Record 19 of Set 13 | ayan
# Processing Record 20 of Set 13 | la rioja
# Processing Record 21 of Set 13 | oktyabrskoye
# Processing Record 22 of Set 13 | flic en flac
# Processing Record 23 of Set 13 | gashua
# Processing Record 24 of Set 13 | kutum
# Processing Record 25 of Set 13 | bucak
# Processing Record 26 of Set 13 | nouadhibou
# Processing Record 27 of Set 13 | kurlovo
# Processing Record 28 of Set 13 | wageningen
# Processing Record 29 of Set 13 | khash
# Processing Record 30 of Set 13 | saint-georges
# Processing Record 31 of Set 13 | wennigsen
# Processing Record 32 of Set 13 | zyryanovsk
# Processing Record 33 of Set 13 | carutapera
# Processing Record 34 of Set 13 | los llanos de aridane
# Processing Record 35 of Set 13 | mackay
# Processing Record 36 of Set 13 | anaco
# Processing Record 37 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 13 | pangody
# Processing Record 39 of Set 13 | ipixuna
# Processing Record 40 of Set 13 | bikaner
# Processing Record 41 of Set 13 | portland
# Processing Record 42 of Set 13 | husavik
# Processing Record 43 of Set 13 | talara
# Processing Record 44 of Set 13 | kattivakkam
# Processing Record 45 of Set 13 | jalu
# Processing Record 46 of Set 13 | saint-joseph
# Processing Record 47 of Set 13 | manjacaze
# Processing Record 48 of Set 13 | yunjinghong
# City not found. Skipping...
# Processing Record 49 of Set 13 | yaan
# Processing Record 50 of Set 13 | maromitsa
# Processing Record 1 of Set 14 | assiniboia
# Processing Record 2 of Set 14 | rudkobing
# Processing Record 3 of Set 14 | tlapehuala
# Processing Record 4 of Set 14 | albury
# Processing Record 5 of Set 14 | fredericksburg
# Processing Record 6 of Set 14 | ferkessedougou
# Processing Record 7 of Set 14 | sao gabriel da cachoeira
# Processing Record 8 of Set 14 | arman
# Processing Record 9 of Set 14 | mazatlan
# Processing Record 10 of Set 14 | boyle
# Processing Record 11 of Set 14 | dakar
# Processing Record 12 of Set 14 | naustdal
# Processing Record 13 of Set 14 | ewo
# Processing Record 14 of Set 14 | ilo
# Processing Record 15 of Set 14 | chardara
# Processing Record 16 of Set 14 | trinidad
# Processing Record 17 of Set 14 | agua verde
# Processing Record 18 of Set 14 | dukat
# Processing Record 19 of Set 14 | shenjiamen
# Processing Record 20 of Set 14 | dataganj
# Processing Record 21 of Set 14 | ola
# Processing Record 22 of Set 14 | tucuman
# Processing Record 23 of Set 14 | nuuk
# Processing Record 24 of Set 14 | miraflores
# Processing Record 25 of Set 14 | pecos
# Processing Record 26 of Set 14 | berlevag
# Processing Record 27 of Set 14 | yuzhno-kurilsk
# Processing Record 28 of Set 14 | dali
# Processing Record 29 of Set 14 | fairbanks
# Processing Record 30 of Set 14 | sayansk
# Processing Record 31 of Set 14 | uberaba
# Processing Record 32 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 33 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 34 of Set 14 | paracuru
# Processing Record 35 of Set 14 | denpasar
# Processing Record 36 of Set 14 | rupert
# Processing Record 37 of Set 14 | sorland
# Processing Record 38 of Set 14 | tlahualilo
# City not found. Skipping...
# Processing Record 39 of Set 14 | maputo
# Processing Record 40 of Set 14 | san quintin
# Processing Record 41 of Set 14 | meridian
# Processing Record 42 of Set 14 | san cristobal
# Processing Record 43 of Set 14 | puerto rondon
# Processing Record 44 of Set 14 | ambon
# Processing Record 45 of Set 14 | olinda
# Processing Record 46 of Set 14 | sturgeon bay
# Processing Record 47 of Set 14 | mortka
# Processing Record 48 of Set 14 | shimoda
# Processing Record 49 of Set 14 | kailua
# Processing Record 50 of Set 14 | grass valley
# Processing Record 1 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 15 | miranorte
# City not found. Skipping...
# Processing Record 3 of Set 15 | batagay-alyta
# Processing Record 4 of Set 15 | roma
# Processing Record 5 of Set 15 | matiguas
# Processing Record 6 of Set 15 | viking
# Processing Record 7 of Set 15 | miandrivazo
# Processing Record 8 of Set 15 | kaniv
# Processing Record 9 of Set 15 | palmer
# Processing Record 10 of Set 15 | kyshtovka
# Processing Record 11 of Set 15 | vizinga
# Processing Record 12 of Set 15 | zhuanghe
# Processing Record 13 of Set 15 | xaxim
# Processing Record 14 of Set 15 | olavarria
# Processing Record 15 of Set 15 | fresno
# Processing Record 16 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 17 of Set 15 | hagi
# Processing Record 18 of Set 15 | limbang
# Processing Record 19 of Set 15 | sao joao da barra
# Processing Record 20 of Set 15 | ishigaki
# Processing Record 21 of Set 15 | palana
# Processing Record 22 of Set 15 | arbazh
# Processing Record 23 of Set 15 | sherlovaya gora
# Processing Record 24 of Set 15 | bubaque
# Processing Record 25 of Set 15 | yar-sale
# Processing Record 26 of Set 15 | imbituba
# Processing Record 27 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 15 | muzhi
# Processing Record 29 of Set 15 | kimbe
# Processing Record 30 of Set 15 | los alamos
# Processing Record 31 of Set 15 | puerto leguizamo
# Processing Record 32 of Set 15 | inhambane
# Processing Record 33 of Set 15 | banikoara
# Processing Record 34 of Set 15 | korla
# Processing Record 35 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 36 of Set 15 | sao felix do xingu
# Processing Record 37 of Set 15 | carson city
# Processing Record 38 of Set 15 | san rafael
# Processing Record 39 of Set 15 | cajati
# Processing Record 40 of Set 15 | cervo
# Processing Record 41 of Set 15 | tateyama
# Processing Record 42 of Set 15 | cookeville
# Processing Record 43 of Set 15 | flin flon
# Processing Record 44 of Set 15 | kamaishi
# Processing Record 45 of Set 15 | yumen
# Processing Record 46 of Set 15 | meyungs
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Yellowknife      CA  62.4560 -114.3525     54.32        43          75
# 1            Kapaa      US  22.0752 -159.3190     84.52        76          75
# 2      Port Alfred      ZA -33.5906   26.8910     59.88        26           0
# 3   Port Elizabeth      ZA -33.9180   25.5701     46.69        61          40
# 4  Port Hawkesbury      CA  45.6169  -61.3485     78.01        87          75
# 5          Ushuaia      AR -54.8000  -68.3000     31.66        86          20
# 6     Puerto Ayora      EC  -0.7393  -90.3518     72.55        93          93
# 7           Avarua      CK -21.2078 -159.7750     78.85        73          20
# 8           Razole      IN  16.4833   81.8333     78.48        88          90
# 9        Busselton      AU -33.6500  115.3333     46.04        78         100
#
#    Wind Speed Current Description
# 0        1.01       broken clouds
# 1        5.99       broken clouds
# 2        9.40           clear sky
# 3        3.44    scattered clouds
# 4        4.00       broken clouds
# 5        3.44          few clouds
# 6        7.00     overcast clouds
# 7       20.71          light rain
# 8        3.31     overcast clouds
# 9        2.06     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
